# %% [markdown]
# # PPA Data Science Group Syllabus
#
# I've put together an outline of how I see this grouping going for the first few months. I'm hoping we can have a bit of a discussion about this and the resources we choose to utilize.
#
# ### Part 1 - General Python
# | Session | Date | Classroom Topic | Homework |
# |:----:|----|----|----|
# | 1 | 2016-01-12 | Intro. to Python and IPython | [ATBS](https://automatetheboringstuff.com/) Chapter 1 |
# | 2 | 2016-01-14 | Review ATBS Chap. 1, [Example ML Notebook](http://nbviewer.ipython.org/github/Sz593/PPA_Notes/tree/master/), and Group Planning | ATBS 2 & 3 |
# | 3 | 2016-01-19 | Review ATBS 2 & 3, Math in Python| ATBS 4 |
# | 4 | 2016-01-21 | Lists, Tuples, Sets, Built-in Functions/Constants 1| ATBS 5 |
# | 5 | 2016-01-26 | Reading and writing from files, `csv` Module, `lambda` Functions | ATBS 6 |
# | 6 | 2016-01-28 | Built-in Functions 2, Comprehensions, and Magic Functions | DMWP 2 - Graphing |
# | 7 | 2016-02-02 | Introduction to Graphing in `matplotlib` and Working Session | Read OOP [Blog Entry](http://inventwithpython.com/blog/2014/12/02/why-is-object-oriented-programming-useful-with-an-role-playing-game-example/) |
# | 8 | 2016-02-04 | Classes and OOP, Generators, `collections` Module, and Working Session | Work on Problem Set |
# | 9 | 2016-02-09 | Working Session | Work on Problem Set |
# | 10 | 2016-02-11| Working Session | ATBS Quiz Generation Problem |
#
# ### Part 2 - Data Analysis in Python
# | Session | Date | Classroom Topic | Homework |
# |:----:|----|----|----|
# | 11 | 2016-02-16 | Review Topics, Begin Data Analysis in Python (DAP) Udacity Course | Data Analysis in Python Lesson 1 |
# | X | 2016-02-18 | CANCELLED  | Finish DAP Lesson 1 |
# | 12 | 2016-02-23 | DAP L1 Review - Exploring Location Alignment Data as a Team | Start DAP Lesson 2 |
# | 13 | 2016-02-25 | Explore Data - Anscombe's Quartet | Finish DAP Lesson 2 |
# | 14 | 2016-03-01 | String Formatting, Running .py Files | Start DAP Lesson 3 (2 weeks) |
# | 15 | 2016-03-03 | Begin Introduction to NumPy and Review Graphing in Matplotlib | Continue DAP Lesson 3 |
# | 16 | 2016-03-08 | Continue Introduction to NumPy, Begin Introduction to Pandas | Finish DAP Lesson 3 |
# | 17 | 2016-03-10 | Continue Introduction to Pandas, Plotting in Pandas, Introduction to Seaborn | TBD|
# | 18 | 2016-03-15 | Finish Introduction to Pandas, Continue Introduction to Seaborn  | TBD |
# | 19 | 2016-03-17 | Finish Introduction to Seaborn | TBD |
#
# ### Part 3 - Data Science in Python
#
# | Session | Date | Classroom Topic | Homework |
# |:----:|:----:|:----:|:----:|
# | X | X | X | X |
#
# ### Part 4 - Machine Learning
#
# | Session | Date | Classroom Topic | Homework |
# |:----:|:----:|:----:|:----:|
# | X | X | X | X |

# %% [markdown]
# ---

# %% [markdown]
# # Intro to Data Analysis
# One of the challenges that we'll see is that this course is written for Python 2.7. Since we're using Python 3.5, there will be some differences in our code.
#
# ### Lesson 1: Data Analysis Process
# When working with these lessons, you won't be able to download the starter code since they hit against Google servers. However, I've downloaded the starter code notebooks put them in the class Jupyer notebook folder, so you can access them from there.
#
# 1. Introduction
# 2. Problems Solved by Data Analysts
# 3. Data Analysis Process
# 4. Downloading Anaconda
#   - You should already have Anaconda installed, since we've been using it for this entire course!
# 5. Intro to CSVs
# 6. CSVs in Python
# 7. Fixing Data Types
# 8. Questions about Student Data
# 9. Investigating the Data
# 10. Problems in the Data
# 11. Missing Engagement Records
# 12. Checking for More Problem Records
# 13. Tracking Down the Remaining Problems
# 14. Refining the Question
# 15. Getting Data from First Week
# 16. Indulge Curiosity
# 17. Exploring Student Engagement
# 18. Debugging Data Analysis Code
# 19. Lessons Completed in First Week
# 20. Number of Visits in the First Week
# 21. Splitting Out Passing Students
# 22. Comparing the Two Student Groups
# 23. Making Histograms
#   - Unlike the video, you should use `%matploblib inline` instead of `%pylab inline`.
# 24. Are Your Results Just Noise?
# 25. Correlation Does Not Imply Causation
# 26. Predicting Based on Many Features
# 27. Communication
# 28. Improving Plots and Sharing Findings
#   - We will be using `seaborn` later on in our class.
# 29. Data Analysis and Related Terms
# 30. Conclusion
# 31. Survey Says!
#
# ### Lesson 2: NumPy and Pandas for 1D Data
#
# 1. Introduction
# 2. Gapminder Data - Solution
# 3. One-Dimensional Data in NumPy and Pandas
# 4. NumPy Arrays
# 5. Vectorized Operations
# 6. Multiplying by a Scalar
# 7. Calculate Overall Completion Rate
# 8. Standardizing Data
# 9. NumPy Index Arrays
# 10. `+` vs. `+=`
# 11. In-Place vs. Not In-Place
# 12. Pandas Series
# 13. Series Indexes
# 14. Vectorized Operations and Series Indexes
# 15. Filling Missing Values
# 16. Pandas series `apply()`
# 17. Plotting in Pandas
# 18. Conclusion
#
# ### Lesson 3: NumPy and Pandas for 2D Data
#
# 1.
